# %% [markdown]
# ## EXTRACCIÓN DE TWEETS DE CHILE

# %% [markdown]
# ### 1. Cargar librerías paquetes

# %%
import tweepy 
import pandas as pd
import numpy as np
import GetOldTweets3 as got
import time
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
from credentials import *

# %% [markdown]
# ### 2. Extraer datos

# %%
text_query = 'covid OR coronavirus OR pandemia OR cuarentena'
since_date = "2020-1-01"
until_date = "2020-9-01"
geocode = "-33.459687,-70.592400"
km = "53.3381km"
count = 2500000
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date , tweet.hashtags ] for tweet in tweets]
tweets_chile1 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_chile1.to_csv('covid_chi_emoji_1.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_chile1  --104103
# Out:
#                    Tweet_Id       Tweet_User_Id       Tweet_User  \
# 0       1300583838830284800           119482388       martiss_39
# 1       1300582792582049793           289099503      Fuck_guerra
# 2       1300582636335882240           106493631       lorefurche
# 3       1300581209857196032            31023357         Tikucita
# 4       1300578681279123456            75286694  radiosanjoaquin
# ...                     ...                 ...              ...
# 104098  1219479256079699968           202434973         BMWchile
# 104099  1219473557987766272           202434973         BMWchile
# 104100  1219381928962469888           161081949  Carlossassarini
# 104101  1219214498743115776  866485668561682432    daniel_notaro
# 104102  1213236313295671297           178121598   leoncioleoncio
#
#                                                      Text  Retweets  \
# 0       Mami yo te quiero mucho pero ya estamos en el ...         0
# ...

# %%
geocode = "-33.819266,-71.120857"
km = "34.14668km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date , tweet.hashtags ] for tweet in tweets]
tweets_chile2 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_chile2.to_csv('covid_chi_emoji_2.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_chile2
# Out:
#                  Tweet_Id        Tweet_User_Id       Tweet_User  \
# 0     1300557187056631808            111996704         jaran_13
# 1     1300529881764294664           2828559745  Mario_Logistico
# 2     1300515988178427907  1131735047390806019     RosaOvalleR1
# 3     1300483015244689414            204053444   VictorguerrajJ
# 4     1300444178447556617            193914536        edorobi73
# ...                   ...                  ...              ...
# 5342  1220833453471563777            134611197       DieguiLost
# 5343  1220732306689798147             61676167           miiwel
# 5344  1220727989912178688            101141425  BLESSLOSDELCODO
# 5345  1220491555833696256            115809922           gajaro
# 5346  1219997129843912704             88081549     Ps_patipelao
#
#                                                    Text  Retweets  Favorites  \
# 0     Hoy en la Est. Los Leones, una pareja de adult...         1          0
# ...

# %%
geocode = "-33.769102,-70.206439"
km = "27.07564km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date , tweet.hashtags ] for tweet in tweets]
tweets_chile3 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_chile3.to_csv('covid_chi_emoji_3.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_chile3
# Out:
#                 Tweet_Id        Tweet_User_Id      Tweet_User  \
# 0    1300403161019154433           2848965665    pao_chavez_m
# 1    1299044577375064070            430351404   andrealizanar
# 2    1298967927446790148           2848965665    pao_chavez_m
# 3    1297167221043666948           2848965665    pao_chavez_m
# 4    1296790516475088896           2848965665    pao_chavez_m
# ..                   ...                  ...             ...
# 351  1232766593874169857  1200165018475663360     pia96016531
# 352  1231698095706120194             60470869         TIRSO48
# 353  1228715404476010496             89676805        david61e
# 354  1227668141586763776            134809695    Aurema_Otero
# 355  1222308103913381890             24365063  polimetralleta
#
#                                                   Text  Retweets  Favorites  \
# 0    Hubo quienes, recibiendo todas las recomendaci...         9         19
# ...

# %% [markdown]
# ### 3. Se guarda la base

# %% [markdown]
# Se juntan las bases

# %%
CHILE_CONCAT = pd.concat([tweets_chile1, tweets_chile2,tweets_chile3])
CHILE_CONCAT.shape
# Out:
# (109806, 9)

# %% [markdown]
# Se eliminan duplicados

# %%
Se eliminan duplicadosCHILE_CONCAT_DISTINCT= CHILE_CONCAT.drop_duplicates()

# %%
CHILE_CONCAT_DISTINCT.reset_index(drop=True, inplace=True)

# %%
CHILE_CONCAT_DISTINCT
# Out:
#                    Tweet_Id  Tweet_User_Id       Tweet_User  \
# 0       1300583838830284800      119482388       martiss_39
# 1       1300582792582049793      289099503      Fuck_guerra
# 2       1300582636335882240      106493631       lorefurche
# 3       1300581209857196032       31023357         Tikucita
# 4       1300578681279123456       75286694  radiosanjoaquin
# ...                     ...            ...              ...
# 104586  1234488632251158529     2396301708   seremisaludohi
# 104587  1233161781297762306      477017226     janox_grunge
# 104588  1228122803272126464     1329546079     velasco_nino
# 104589  1226913119479500800     1630889779   canales_israel
# 104590  1222733073130848256     2453850859  Felipecornejomo
#
#                                                      Text  Retweets  \
# 0       Mami yo te quiero mucho pero ya estamos en el ...         0
# 1       Mi mamá me pega chalazos todos los días un día...         0
# ...

# %% [markdown]
# Se agrega columna de país con la etiqueta "Chi" de Chile

# %%
CHILE_CONCAT_DISTINCT['Pais'] = 'Chi'

# %%
CHILE_CONCAT_DISTINCT
# Out:
#                    Tweet_Id  Tweet_User_Id       Tweet_User  \
# 0       1300583838830284800      119482388       martiss_39
# 1       1300582792582049793      289099503      Fuck_guerra
# 2       1300582636335882240      106493631       lorefurche
# 3       1300581209857196032       31023357         Tikucita
# 4       1300578681279123456       75286694  radiosanjoaquin
# ...                     ...            ...              ...
# 104586  1234488632251158529     2396301708   seremisaludohi
# 104587  1233161781297762306      477017226     janox_grunge
# 104588  1228122803272126464     1329546079     velasco_nino
# 104589  1226913119479500800     1630889779   canales_israel
# 104590  1222733073130848256     2453850859  Felipecornejomo
#
#                                                      Text  Retweets  \
# 0       Mami yo te quiero mucho pero ya estamos en el ...         0
# 1       Mi mamá me pega chalazos todos los días un día...         0
# ...

# %% [markdown]
# Se guarda la base

# %%
CHILE_CONCAT_DISTINCT.to_csv('CHILE_CONCAT_DISTINCT.csv', header=True, index=False, encoding='utf-8-sig')
