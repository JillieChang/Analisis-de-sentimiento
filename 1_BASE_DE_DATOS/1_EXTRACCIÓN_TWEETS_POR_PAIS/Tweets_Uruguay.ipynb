# %% [markdown]
# ## EXTRACCIÓN DE TWEETS DE URUGUAY

# %% [markdown]
# ### 1. Cargar librerías paquetes

# %%
import pandas as pd
import numpy as np
import GetOldTweets3 as got
import time
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Extraer datos

# %%
geocode = "-34.826967,-56.398748"
km = "3.71705km"
text_query = 'covid OR coronavirus OR pandemia OR cuarentena'
since_date = "2020-1-01"
until_date = "2020-9-01"
count = 2500000
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date, tweet.hashtags] for tweet in tweets]
tweets_uruguay1 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_Uruguay1.to_csv('covid_uru_emoji_1.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_uruguay1

# %%
geocode = "-34.735608,-56.314987"
km = "3.40421km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date, tweet.hashtags] for tweet in tweets]
tweets_uruguay2 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_Uruguay2.to_csv('covid_uru_emoji_2.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_uruguay2

# %%
geocode = "-34.833068,-56.289271"
km = "8.62334km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date, tweet.hashtags] for tweet in tweets]
tweets_uruguay3 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_Uruguay3.to_csv('covid_uru_emoji_3.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_uruguay3

# %%
geocode = "-34.772924,-56.166154"
km = "5.48681km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date, tweet.hashtags] for tweet in tweets]
tweets_uruguay4 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_Uruguay4.to_csv('covid_uru_emoji_4.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_uruguay4

# %%
geocode = "-34.869895,-56.144182"
km = "8.49843km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date, tweet.hashtags] for tweet in tweets]
tweets_uruguay5 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_Uruguay5.to_csv('covid_uru_emoji_5.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_uruguay5

# %%
geocode = "-34.794835,-56.069166"
km = "2.53155km"
tweetCriteria = got.manager.TweetCriteria().setQuerySearch(text_query).setNear(geocode).setWithin(km).setSince(since_date).setUntil(until_date).setMaxTweets(count).setEmoji("unicode")
tweets = got.manager.TweetManager.getTweets(tweetCriteria)
tweets_list = [[tweet.id, tweet.author_id, tweet.username, tweet.text, tweet.retweets, tweet.favorites, tweet.replies, tweet.date, tweet.hashtags] for tweet in tweets]
tweets_uruguay6 = pd.DataFrame(tweets_list, columns = ['Tweet_Id', 'Tweet_User_Id', 'Tweet_User', 'Text','Retweets', 'Favorites', 'Replies', 'Datetime', 'hashtags'])
tweets_Uruguay6.to_csv('covid_uru_emoji_6.csv', header=True, index=False, encoding='utf-8-sig')

# %%
tweets_uruguay6

# %%
#"-34.826967,-56.398748" km="3.71705km"    tweets_uruguay1 
#"-34.735608,-56.314987" km="3.40421km"    tweets_uruguay2
#"-34.833068,-56.289271" km="8.62334km"    tweets_uruguay3
#"-34.772924,-56.166154" km="5.48681km"    tweets_uruguay4
#"-34.869895,-56.144182" km="8.49843km"    tweets_uruguay5
#"-34.794835,-56.069166" km="2.53155km"    tweets_uruguay6

# %% [markdown]
# ### 3. Se guarda la base

# %% [markdown]
# Se juntan las bases

# %%
URUGUAY_CONCAT = pd.concat([tweets_uruguay1, tweets_uruguay2,tweets_uruguay3, tweets_uruguay4, tweets_uruguay5, tweets_uruguay6])
URUGUAY_CONCAT.shape

# %% [markdown]
# Se eliminan duplicados

# %%
URUGUAY_CONCAT_DISTINCT= URUGUAY_CONCAT.drop_duplicates()

# %%
URUGUAY_CONCAT_DISTINCT.reset_index(drop=True, inplace=True)

# %%
URUGUAY_CONCAT_DISTINCT.to_csv('URUGUAY_CONCAT_DISTINCT.csv', header=True, index=False, encoding='utf-8-sig')

# %% [markdown]
# Se agrega columna de país con la etiqueta "Uru" de Uruguay

# %%
URUGUAY_CONCAT_DISTINCT['Pais'] = 'Uru'
# Out:
# C:\Users\Pilar Villena\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
URUGUAY_CONCAT_DISTINCT
# Out:
#                   Tweet_Id        Tweet_User_Id       Tweet_User  \
# 0      1300465503564173313            480666205           DrPasm
# 1      1300264361466920960             85148912       jocaritomb
# 2      1300185866871042048            170478394       diegob1946
# 3      1299935511801458693  1252327240731365381  MesaLGBTIusaque
# 4      1299892408465993728             85148912       jocaritomb
# ...                    ...                  ...              ...
# 97082  1241224027991048199  1230551625531416579     cabreracundi
# 97083  1240687422855245824  1230551625531416579     cabreracundi
# 97084  1238643382936797184  1230551625531416579     cabreracundi
# 97085  1267878146688368642  1230551625531416579     cabreracundi
# 97086  1254506021302808578  1230551625531416579     cabreracundi
#
#                                                     Text  Retweets  Favorites  \
# 0      El antes y el durante la pandemia comunista ch...         0          0
# ...

# %% [markdown]
# Se guarda la base

# %%
URUGUAY_CONCAT_DISTINCT.to_csv('URUGUAY_CONCAT_DISTINCT.csv', header=True, index=False, encoding='utf-8-sig')
